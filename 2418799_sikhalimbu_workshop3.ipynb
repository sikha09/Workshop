# %%
#supervised Machine learning
#level dataset
#Types
#Classification(discrete data) ir gives data similat to the surroundings

#Regression(continuous data) it gives the average data
#What is model?
#a function simply capture the nature of a data
#family of a model is hypothesis space

#parameter machine learning

#Decision process
#Error Function
#optimaization process

#Generalization

# %% [markdown]
# Loading and Cleaning Data.

# %% [markdown]
# Problem - 1: Perform a classification task with knn from scratch.
# 1. Load the Dataset:
# • Read the dataset into a pandas DataFrame.
# • Display the first few rows and perform exploratory data analysis (EDA) to understand the dataset
# (e.g., check data types, missing values, summary statistics).

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/diabetes.csv")
df.head()#gives the index upto 5
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes#checks the datatype
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#checks the missing value
missing_info=(df.isnull().sum())
print("\nMissing values:\n",missing_info)
# Out:
# Missing values:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
(df.describe())#summary statistics
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Handle Missing Data:
# • Handle any missing values appropriately, either by dropping or imputing them based on the data.

# %%
# Handle missing values
for column in df.columns:
  if missing_info[column] > 1: # If more than 10% missing
    df[column].fillna(df[column].mean(), inplace=True)
  else: # If less than 10% missing
    df.dropna(subset=[column], inplace=True)
print("\nMissing values after processing:\n", df.isnull().sum())
# Out:
# Missing values after processing:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Feature Engineering:
# • Separate the feature matrix (X) and target variable (y).
# • Perform a train - test split from scratch using a 70% − 30% ratio.

# %%
import numpy as np
X=df.drop(columns=['Glucose']).values#convert features to Numpy array
y=df['Glucose'].values#convert target to Numpy array

#define a function for train-test split from scratch

def train_test_spilt_scratch(X,y, test_size=0.3, random_seed=42):

# %% [markdown]
# Feature Engineering:
# • Separate the feature matrix (X) and target variable (y).
# • Perform a train - test split from scratch using a 70% − 30% ratio.
